# %%
# Core libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from copy import deepcopy

# SciPy for statistical analysis
from scipy import stats
from scipy.stats import t

# Scikit-learn utilities
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
    confusion_matrix, balanced_accuracy_score, ConfusionMatrixDisplay, classification_report
)
from sklearn.metrics import precision_recall_curve


import matplotlib.pyplot as plt


from sklearn.utils import resample, class_weight
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer
from sklearn.ensemble import RandomForestRegressor
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split


# TensorFlow and Keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input, Concatenate
from tensorflow.keras.callbacks import EarlyStopping
import keras.backend as K



import csv
import os

# %%
# ===========================
# Load and preprocess dataset
# ===========================

from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/Shared drives/ABCD_Model/for_JS_final_withgroup.csv'
df = pd.read_csv(file_path)


# Extract numeric site ID from 'site_id_l.baseline_year_1_arm_1'
df['site'] = df['site_id_l.baseline_year_1_arm_1'].str.extract(r'(\d+)$').astype(int)

# Define features for each timepoint
features_baseline = [
    #'interview_age.baseline_year_1_arm_1',
    'KSADSintern.baseline_year_1_arm_1',
    'nihtbx_cryst_agecorrected.baseline_year_1_arm_1',
    'ACEs.baseline_year_1_arm_1',
    'avgPFCthick_QA.baseline_year_1_arm_1',
    'rsfmri_c_ngd_cgc_ngd_cgc_QA.baseline_year_1_arm_1',
    'rsfmri_c_ngd_dt_ngd_dt_QA.baseline_year_1_arm_1'
]

features_followup = [
    #'interview_age.2_year_follow_up_y_arm_1',
    'KSADSintern.2_year_follow_up_y_arm_1',
    'nihtbx_cryst_agecorrected.2_year_follow_up_y_arm_1',
    'ACEs.2_year_follow_up_y_arm_1',
    'avgPFCthick_QA.2_year_follow_up_y_arm_1',
    'rsfmri_c_ngd_cgc_ngd_cgc_QA.2_year_follow_up_y_arm_1',
    'rsfmri_c_ngd_dt_ngd_dt_QA.2_year_follow_up_y_arm_1',
]

features_all_time = features_baseline + features_followup

# Define cross-sectional features: all other numeric columns not in features_all_time or site/group columns
cross_sectional_features = [
    'rel_family_id',
    #'demo_sex_v2',
    #'race_ethnicity',
    'acs_raked_propensity_score',
    'speechdelays',
    'motordelays',
    'fam_history_8_yes_no',
    ]
# ========================
# Clean data
# ========================



for col in features_all_time + cross_sectional_features:
    df[col] = df[col].astype(str).str.strip()
    df.loc[df[col] == '', col] = np.nan
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Step 2: Drop rows with missing values in key column(s)
df.dropna(subset=features_all_time + ['group_PDvLP_3timepoint'], inplace=True)

# Step 3: KNN Imputation on features (assumes all are numeric now)
#imputer = KNNImputer(n_neighbors=5) #comment these two lines for non data imputation
#df[features_all_time + cross_sectional_features] = imputer.fit_transform(df[features_all_time + cross_sectional_features])

print(f"Total samples after cleaning: {len(df)}")
print(f"1s: {len(df[df['group_PDvLP_3timepoint'] == 1])} 0s: {len(df[df['group_PDvLP_3timepoint'] == 0])}")
site_ids = df['site'].unique()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Total samples after cleaning: 4153
# 1s: 160 0s: 3993

# %%
def build_LSTM_model(
    timesteps,
    ts_features,
    cross_features,
    lstm_units=64,
    dropout_rate=0.3,
    dense_units=32,
    alpha=0.75  # for focal loss if you want to pass it here
):
    # Time series input
    input_ts = Input(shape=(timesteps, ts_features), name='time_series_input')
    lstm_out = LSTM(lstm_units, return_sequences=False)(input_ts)
    lstm_out = Dropout(dropout_rate)(lstm_out)

    # Cross-sectional input
    input_cross = Input(shape=(cross_features,), name='cross_sectional_input')

    # Concatenate LSTM output and cross-sectional data
    concatenated = Concatenate()([lstm_out, input_cross])

    # Dense layers
    dense1 = Dense(dense_units, activation='relu')(concatenated)
    output = Dense(1, activation='sigmoid')(dense1)

    model = Model(inputs=[input_ts, input_cross], outputs=output)
    model.compile(optimizer='adam', loss=focal_loss(alpha=alpha), metrics=['accuracy']) #focal loss
    return model

# %%
def focal_loss(gamma=2., alpha=0.75):
    def focal_loss_fixed(y_true, y_pred):
        epsilon = K.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred) - (1 - y_true) * tf.math.log(1 - y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma) * y_true + (1 - alpha) * tf.pow(y_pred, gamma) * (1 - y_true)
        loss = weight * cross_entropy

        return tf.reduce_mean(loss)

    return focal_loss_fixed

# %%
def run_losocv_lstm(
    df,
    features_baseline,
    features_followup,
    cross_sectional_features,
    site_column='site',
    label_column='group_PDvLP_3timepoint',
    lstm_units=64,
    dropout_rate=0.3,
    dense_units=32,
    alpha=0.75,
    batch_size=16,
    verbose=0
):
    site_ids = df[site_column].unique()
    site_metrics = []

    for test_site in site_ids:
        print(f"\n==== Testing on site {test_site} ====")

        df_train = df[df[site_column] != test_site]
        df_test = df[df[site_column] == test_site]

        # === Time series features ===
        X_train_ts, y_train = [], []
        for _, row in df_train.iterrows():
            baseline = row[features_baseline].values.astype(np.float32)
            followup = row[features_followup].values.astype(np.float32)


            if baseline.shape != followup.shape:
                continue
            seq = np.stack([baseline, followup])
            X_train_ts.append(seq)
            y_train.append(row[label_column])

        X_test_ts, y_test = [], []
        for _, row in df_test.iterrows():
            baseline = row[features_baseline].values.astype(np.float32)
            followup = row[features_followup].values.astype(np.float32)
            if baseline.shape != followup.shape:
                continue
            seq = np.stack([baseline, followup])
            X_test_ts.append(seq)
            y_test.append(row[label_column])

        X_train_ts = np.array(X_train_ts)
        X_test_ts = np.array(X_test_ts)
        y_train = np.array(y_train).astype(int)
        y_test = np.array(y_test).astype(int)



        if len(X_train_ts) == 0 or len(X_test_ts) == 0:
            print(f"Skipping site {test_site} due to no valid samples.")
            continue

        # === Cross-sectional features ===
        X_train_cross = df_train[cross_sectional_features].copy()
        X_test_cross = df_test[cross_sectional_features].copy()

        imputer = KNNImputer(n_neighbors=5)
        X_train_cross = imputer.fit_transform(X_train_cross)
        X_test_cross = imputer.transform(X_test_cross)

        # === Normalize time series ===
        scaler_ts = StandardScaler()
        X_train_ts_flat = X_train_ts.reshape(-1, X_train_ts.shape[2])
        X_test_ts_flat = X_test_ts.reshape(-1, X_test_ts.shape[2])

        X_train_ts_scaled = scaler_ts.fit_transform(X_train_ts_flat).reshape(X_train_ts.shape)
        X_test_ts_scaled = scaler_ts.transform(X_test_ts_flat).reshape(X_test_ts.shape)

        # === Normalize cross-sectional ===
        scaler_cross = StandardScaler()
        X_train_cross_scaled = scaler_cross.fit_transform(X_train_cross)
        X_test_cross_scaled = scaler_cross.transform(X_test_cross)

        # === Build and train model ===
        model = build_LSTM_model(
            timesteps=X_train_ts_scaled.shape[1],
            ts_features=X_train_ts_scaled.shape[2],
            cross_features=X_train_cross_scaled.shape[1],
            lstm_units=lstm_units,
            dropout_rate=dropout_rate,
            dense_units=dense_units,
            alpha=alpha
        )

        early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

        model.fit(
            [X_train_ts_scaled, X_train_cross_scaled], y_train,
            epochs=20,
            batch_size=batch_size,
            validation_split=0.1,
            callbacks=[early_stop],
            verbose=verbose
        )

        # === Evaluate ===
        y_pred_probs = model.predict([X_test_ts_scaled, X_test_cross_scaled]).flatten()
        y_pred = (y_pred_probs > 0.5).astype(int)

        if np.isnan(y_pred_probs).any():
            print("NaNs detected in prediction probabilities, skipping AUC calculation for this site.")
            auc = float('nan')
        elif len(np.unique(y_test)) == 2:
            auc = roc_auc_score(y_test, y_pred_probs)
        else:
            auc = float('nan')

        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred, zero_division=0)
        rec = recall_score(y_test, y_pred, zero_division=0)
        f1 = f1_score(y_test, y_pred, zero_division=0)

        cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
        if cm.shape == (2, 2):
            tn, fp, fn, tp = cm.ravel()
        else:
            print(f"Confusion matrix is not 2x2 for site {test_site}. It is:\n{cm}")
            tn = fp = fn = tp = 0

        npv = tn / (tn + fn) if (tn + fn) > 0 else 0
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0

        print(f"Accuracy:  {acc:.3f}")
        print(f"Precision: {prec:.3f}")
        print(f"Recall:    {rec:.3f}")
        print(f"F1 Score:  {f1:.3f}")
        print(f"AUC:       {auc:.3f}")
        print(f"Negative Predictive Value (NPV): {npv:.2f}")
        print(f"Specificity: {specificity:.3f}")

        site_metrics.append((test_site, acc, prec, rec, npv, auc, specificity, f1))

    return site_metrics

# %%
# Write header once, if file doesn't exist

csv_file = '/content/drive/Shared drives/ABCD_Model/Explainability/no_demos_feature_ablation_results.csv'
fieldnames = ['ablated_feature', 'feature_type',  'Accuracy', 'Precision', 'Recall', 'NPV', 'AUC', 'Specificity', 'F1 Score']





if not os.path.isfile(csv_file):
    with open(csv_file, mode='w', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()

def write_result_to_csv(result_dict):
    with open(csv_file, mode='a', newline='') as f:
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writerow(result_dict)

def get_existing_ablated_features(csv_file):
    if not os.path.isfile(csv_file):
        return set()

    existing = set()
    with open(csv_file, mode='r', newline='') as f:
        reader = csv.DictReader(f)
        for row in reader:
            existing.add(row['ablated_feature'])
    return existing

def core_name(feat):
    return feat.split('.')[0]

# %%
results = []


baseline_core_to_full = {core_name(f): f for f in features_baseline}
followup_core_to_full = {core_name(f): f for f in features_followup}

# All core features (assuming same set in baseline and follow-up)
core_features = list(baseline_core_to_full.keys())

existing_ablated = get_existing_ablated_features(csv_file)

for core_feat in core_features:
    if core_feat in existing_ablated:
        print(f"Skipping {core_feat} — already in results.")
        continue

    print(f"\n==== Ablating time-series feature: {core_feat} ====")

    features_baseline_ablate = [f for f in features_baseline if core_name(f) != core_feat]
    features_followup_ablate = [f for f in features_followup if core_name(f) != core_feat]

    print(f"Baseline features: {features_baseline_ablate}")
    print(f"Follow-up features: {features_followup_ablate}")

    metrics = run_losocv_lstm(
        df,
        features_baseline=features_baseline_ablate,
        features_followup=features_followup_ablate,
        cross_sectional_features=cross_sectional_features,
        verbose=0
    )

    mean_metrics = {
        'ablated_feature': core_feat,
        'feature_type': 'time_series',
        'Accuracy': np.nanmean([m[1] for m in metrics]),
        'Precision': np.nanmean([m[2] for m in metrics]),
        'Recall': np.nanmean([m[3] for m in metrics]),
        'NPV': np.nanmean([m[4] for m in metrics]),
        'AUC': np.nanmean([m[5] for m in metrics]),
        'Specificity': np.nanmean([m[6] for m in metrics]),
        'F1 Score': np.nanmean([m[7] for m in metrics])
    }

    results.append(mean_metrics)
    write_result_to_csv(mean_metrics)
    print(f"AUC after ablating {core_feat}: {mean_metrics['AUC']:.4f}")
# Out:
# ==== Ablating time-series feature: KSADSintern ====
# Baseline features: ['nihtbx_cryst_agecorrected.baseline_year_1_arm_1', 'ACEs.baseline_year_1_arm_1', 'avgPFCthick_QA.baseline_year_1_arm_1', 'rsfmri_c_ngd_cgc_ngd_cgc_QA.baseline_year_1_arm_1', 'rsfmri_c_ngd_dt_ngd_dt_QA.baseline_year_1_arm_1']
# Follow-up features: ['nihtbx_cryst_agecorrected.2_year_follow_up_y_arm_1', 'ACEs.2_year_follow_up_y_arm_1', 'avgPFCthick_QA.2_year_follow_up_y_arm_1', 'rsfmri_c_ngd_cgc_ngd_cgc_QA.2_year_follow_up_y_arm_1', 'rsfmri_c_ngd_dt_ngd_dt_QA.2_year_follow_up_y_arm_1']
#
# ==== Testing on site 21 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy:  0.931
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.706
# Negative Predictive Value (NPV): 0.94
# Specificity: 0.995
#
# ==== Testing on site 11 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Accuracy:  0.979
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.572
# Negative Predictive Value (NPV): 0.98
# Specificity: 1.000
#
# ==== Testing on site 4 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Accuracy:  0.950
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.485
# Negative Predictive Value (NPV): 0.95
# Specificity: 1.000
#
# ==== Testing on site 5 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Accuracy:  0.958
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.548
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 6 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
# Accuracy:  0.977
# Precision: 0.333
# Recall:    0.200
# F1 Score:  0.250
# AUC:       0.667
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.992
#
# ==== Testing on site 20 ====
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Accuracy:  0.923
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.740
# Negative Predictive Value (NPV): 0.92
# Specificity: 1.000
#
# ==== Testing on site 1 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Accuracy:  0.942
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.840
# Negative Predictive Value (NPV): 0.94
# Specificity: 1.000
#
# ==== Testing on site 18 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Accuracy:  0.947
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.813
# Negative Predictive Value (NPV): 0.95
# Specificity: 1.000
#
# ==== Testing on site 3 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Accuracy:  0.976
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.656
# Negative Predictive Value (NPV): 0.98
# Specificity: 1.000
#
# ==== Testing on site 12 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Accuracy:  0.952
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.788
# Negative Predictive Value (NPV): 0.95
# Specificity: 1.000
#
# ==== Testing on site 14 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Accuracy:  0.981
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.594
# Negative Predictive Value (NPV): 0.98
# Specificity: 1.000
#
# ==== Testing on site 10 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Accuracy:  0.910
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.691
# Negative Predictive Value (NPV): 0.91
# Specificity: 1.000
#
# ==== Testing on site 16 ====
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Accuracy:  0.977
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.865
# Negative Predictive Value (NPV): 0.98
# Specificity: 1.000
#
# ==== Testing on site 13 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step
# Accuracy:  0.971
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.600
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.995
#
# ==== Testing on site 9 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Accuracy:  0.955
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.757
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 2 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Accuracy:  0.986
# Precision: 1.000
# Recall:    0.250
# F1 Score:  0.400
# AUC:       0.650
# Negative Predictive Value (NPV): 0.99
# Specificity: 1.000
#
# ==== Testing on site 15 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Accuracy:  0.977
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.332
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.992
#
# ==== Testing on site 19 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Accuracy:  0.959
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.676
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.995
#
# ==== Testing on site 8 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Accuracy:  0.968
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.689
# Negative Predictive Value (NPV): 0.97
# Specificity: 1.000
#
# ==== Testing on site 17 ====
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Accuracy:  0.987
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.502
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.996
#
# ==== Testing on site 7 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# Accuracy:  0.985
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.940
# Negative Predictive Value (NPV): 0.99
# Specificity: 1.000
#
# ==== Testing on site 22 ====
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Accuracy:  1.000
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       nan
# Negative Predictive Value (NPV): 1.00
# Specificity: 1.000
# AUC after ablating KSADSintern: 0.6719
#
# ==== Ablating time-series feature: nihtbx_cryst_agecorrected ====
# Baseline features: ['KSADSintern.baseline_year_1_arm_1', 'ACEs.baseline_year_1_arm_1', 'avgPFCthick_QA.baseline_year_1_arm_1', 'rsfmri_c_ngd_cgc_ngd_cgc_QA.baseline_year_1_arm_1', 'rsfmri_c_ngd_dt_ngd_dt_QA.baseline_year_1_arm_1']
# Follow-up features: ['KSADSintern.2_year_follow_up_y_arm_1', 'ACEs.2_year_follow_up_y_arm_1', 'avgPFCthick_QA.2_year_follow_up_y_arm_1', 'rsfmri_c_ngd_cgc_ngd_cgc_QA.2_year_follow_up_y_arm_1', 'rsfmri_c_ngd_dt_ngd_dt_QA.2_year_follow_up_y_arm_1']
#
# ==== Testing on site 21 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Accuracy:  0.940
# Precision: 0.571
# Recall:    0.286
# F1 Score:  0.381
# AUC:       0.747
# Negative Predictive Value (NPV): 0.95
# Specificity: 0.985
#
# ==== Testing on site 11 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Accuracy:  0.993
# Precision: 0.750
# Recall:    1.000
# F1 Score:  0.857
# AUC:       0.998
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.993
#
# ==== Testing on site 4 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Accuracy:  0.936
# Precision: 0.300
# Recall:    0.214
# F1 Score:  0.250
# AUC:       0.732
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.974
#
# ==== Testing on site 5 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Accuracy:  0.950
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.774
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.991
#
# ==== Testing on site 6 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Accuracy:  0.977
# Precision: 0.400
# Recall:    0.400
# F1 Score:  0.400
# AUC:       0.765
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.988
#
# ==== Testing on site 20 ====
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Accuracy:  0.935
# Precision: 0.700
# Recall:    0.269
# F1 Score:  0.389
# AUC:       0.838
# Negative Predictive Value (NPV): 0.94
# Specificity: 0.990
#
# ==== Testing on site 1 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Accuracy:  0.951
# Precision: 1.000
# Recall:    0.167
# F1 Score:  0.286
# AUC:       0.813
# Negative Predictive Value (NPV): 0.95
# Specificity: 1.000
#
# ==== Testing on site 18 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Accuracy:  0.947
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.963
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.981
#
# ==== Testing on site 3 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step
# Accuracy:  0.970
# Precision: 0.333
# Recall:    0.250
# F1 Score:  0.286
# AUC:       0.777
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.988
#
# ==== Testing on site 12 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Accuracy:  0.958
# Precision: 1.000
# Recall:    0.125
# F1 Score:  0.222
# AUC:       0.908
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 14 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Accuracy:  0.996
# Precision: 1.000
# Recall:    0.800
# F1 Score:  0.889
# AUC:       0.889
# Negative Predictive Value (NPV): 1.00
# Specificity: 1.000
#
# ==== Testing on site 10 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Accuracy:  0.914
# Precision: 0.571
# Recall:    0.167
# F1 Score:  0.258
# AUC:       0.709
# Negative Predictive Value (NPV): 0.92
# Specificity: 0.988
#
# ==== Testing on site 16 ====
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Accuracy:  0.984
# Precision: 0.800
# Recall:    0.400
# F1 Score:  0.533
# AUC:       0.872
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.998
#
# ==== Testing on site 13 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Accuracy:  0.981
# Precision: 0.571
# Recall:    0.800
# F1 Score:  0.667
# AUC:       0.988
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.985
#
# ==== Testing on site 9 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Accuracy:  0.948
# Precision: 0.400
# Recall:    0.333
# F1 Score:  0.364
# AUC:       0.906
# Negative Predictive Value (NPV): 0.97
# Specificity: 0.977
#
# ==== Testing on site 2 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Accuracy:  0.973
# Precision: 0.250
# Recall:    0.250
# F1 Score:  0.250
# AUC:       0.617
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.986
#
# ==== Testing on site 15 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Accuracy:  0.932
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.927
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.947
#
# ==== Testing on site 19 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy:  0.959
# Precision: 0.429
# Recall:    0.429
# F1 Score:  0.429
# AUC:       0.793
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.979
#
# ==== Testing on site 8 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Accuracy:  0.968
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.648
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.989
#
# ==== Testing on site 17 ====
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Accuracy:  0.983
# Precision: 0.250
# Recall:    0.500
# F1 Score:  0.333
# AUC:       0.983
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.987
#
# ==== Testing on site 7 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Accuracy:  0.971
# Precision: 0.333
# Recall:    1.000
# F1 Score:  0.500
# AUC:       1.000
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.970
#
# ==== Testing on site 22 ====
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Accuracy:  1.000
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       nan
# Negative Predictive Value (NPV): 1.00
# Specificity: 1.000
# AUC after ablating nihtbx_cryst_agecorrected: 0.8403
#
# ==== Ablating time-series feature: ACEs ====
# Baseline features: ['KSADSintern.baseline_year_1_arm_1', 'nihtbx_cryst_agecorrected.baseline_year_1_arm_1', 'avgPFCthick_QA.baseline_year_1_arm_1', 'rsfmri_c_ngd_cgc_ngd_cgc_QA.baseline_year_1_arm_1', 'rsfmri_c_ngd_dt_ngd_dt_QA.baseline_year_1_arm_1']
# Follow-up features: ['KSADSintern.2_year_follow_up_y_arm_1', 'nihtbx_cryst_agecorrected.2_year_follow_up_y_arm_1', 'avgPFCthick_QA.2_year_follow_up_y_arm_1', 'rsfmri_c_ngd_cgc_ngd_cgc_QA.2_year_follow_up_y_arm_1', 'rsfmri_c_ngd_dt_ngd_dt_QA.2_year_follow_up_y_arm_1']
#
# ==== Testing on site 21 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Accuracy:  0.936
# Precision: 0.500
# Recall:    0.286
# F1 Score:  0.364
# AUC:       0.683
# Negative Predictive Value (NPV): 0.95
# Specificity: 0.980
#
# ==== Testing on site 11 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Accuracy:  0.986
# Precision: 0.667
# Recall:    0.667
# F1 Score:  0.667
# AUC:       0.993
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.993
#
# ==== Testing on site 4 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Accuracy:  0.943
# Precision: 0.375
# Recall:    0.214
# F1 Score:  0.273
# AUC:       0.620
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.981
#
# ==== Testing on site 5 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Accuracy:  0.942
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.920
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.983
#
# ==== Testing on site 6 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Accuracy:  0.973
# Precision: 0.375
# Recall:    0.600
# F1 Score:  0.462
# AUC:       0.782
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.980
#
# ==== Testing on site 20 ====
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Accuracy:  0.932
# Precision: 0.714
# Recall:    0.192
# F1 Score:  0.303
# AUC:       0.772
# Negative Predictive Value (NPV): 0.94
# Specificity: 0.994
#
# ==== Testing on site 1 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy:  0.922
# Precision: 0.333
# Recall:    0.333
# F1 Score:  0.333
# AUC:       0.763
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.959
#
# ==== Testing on site 18 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Accuracy:  0.956
# Precision: 0.600
# Recall:    0.500
# F1 Score:  0.545
# AUC:       0.871
# Negative Predictive Value (NPV): 0.97
# Specificity: 0.981
#
# ==== Testing on site 3 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Accuracy:  0.957
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.680
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.981
#
# ==== Testing on site 12 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Accuracy:  0.952
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.777
# Negative Predictive Value (NPV): 0.95
# Specificity: 1.000
#
# ==== Testing on site 14 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Accuracy:  0.981
# Precision: 0.500
# Recall:    0.400
# F1 Score:  0.444
# AUC:       0.924
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.992
#
# ==== Testing on site 10 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Accuracy:  0.917
# Precision: 0.667
# Recall:    0.167
# F1 Score:  0.267
# AUC:       0.736
# Negative Predictive Value (NPV): 0.92
# Specificity: 0.992
#
# ==== Testing on site 16 ====
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# Accuracy:  0.984
# Precision: 0.800
# Recall:    0.400
# F1 Score:  0.533
# AUC:       0.882
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.998
#
# ==== Testing on site 13 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# Accuracy:  0.990
# Precision: 0.800
# Recall:    0.800
# F1 Score:  0.800
# AUC:       0.975
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.995
#
# ==== Testing on site 9 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Accuracy:  0.963
# Precision: 0.667
# Recall:    0.333
# F1 Score:  0.444
# AUC:       0.885
# Negative Predictive Value (NPV): 0.97
# Specificity: 0.992
#
# ==== Testing on site 2 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Accuracy:  0.973
# Precision: 0.250
# Recall:    0.250
# F1 Score:  0.250
# AUC:       0.764
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.986
#
# ==== Testing on site 15 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Accuracy:  0.962
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.954
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.977
#
# ==== Testing on site 19 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Accuracy:  0.964
# Precision: 0.500
# Recall:    0.429
# F1 Score:  0.462
# AUC:       0.902
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.984
#
# ==== Testing on site 8 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Accuracy:  0.968
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.652
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.989
#
# ==== Testing on site 17 ====
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Accuracy:  0.983
# Precision: 0.333
# Recall:    1.000
# F1 Score:  0.500
# AUC:       0.983
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.983
#
# ==== Testing on site 7 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Accuracy:  0.971
# Precision: 0.333
# Recall:    1.000
# F1 Score:  0.500
# AUC:       1.000
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.970
#
# ==== Testing on site 22 ====
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# Accuracy:  0.875
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       nan
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.875
# AUC after ablating ACEs: 0.8341
#
# ==== Ablating time-series feature: avgPFCthick_QA ====
# Baseline features: ['KSADSintern.baseline_year_1_arm_1', 'nihtbx_cryst_agecorrected.baseline_year_1_arm_1', 'ACEs.baseline_year_1_arm_1', 'rsfmri_c_ngd_cgc_ngd_cgc_QA.baseline_year_1_arm_1', 'rsfmri_c_ngd_dt_ngd_dt_QA.baseline_year_1_arm_1']
# Follow-up features: ['KSADSintern.2_year_follow_up_y_arm_1', 'nihtbx_cryst_agecorrected.2_year_follow_up_y_arm_1', 'ACEs.2_year_follow_up_y_arm_1', 'rsfmri_c_ngd_cgc_ngd_cgc_QA.2_year_follow_up_y_arm_1', 'rsfmri_c_ngd_dt_ngd_dt_QA.2_year_follow_up_y_arm_1']
#
# ==== Testing on site 21 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Accuracy:  0.940
# Precision: 0.571
# Recall:    0.286
# F1 Score:  0.381
# AUC:       0.705
# Negative Predictive Value (NPV): 0.95
# Specificity: 0.985
#
# ==== Testing on site 11 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Accuracy:  0.979
# Precision: 0.500
# Recall:    0.667
# F1 Score:  0.571
# AUC:       0.985
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.985
#
# ==== Testing on site 4 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Accuracy:  0.940
# Precision: 0.333
# Recall:    0.214
# F1 Score:  0.261
# AUC:       0.708
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.978
#
# ==== Testing on site 5 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Accuracy:  0.942
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.741
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.983
#
# ==== Testing on site 6 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Accuracy:  0.969
# Precision: 0.286
# Recall:    0.400
# F1 Score:  0.333
# AUC:       0.748
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.980
#
# ==== Testing on site 20 ====
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy:  0.932
# Precision: 0.667
# Recall:    0.231
# F1 Score:  0.343
# AUC:       0.824
# Negative Predictive Value (NPV): 0.94
# Specificity: 0.990
#
# ==== Testing on site 1 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step
# Accuracy:  0.932
# Precision: 0.400
# Recall:    0.333
# F1 Score:  0.364
# AUC:       0.826
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.969
#
# ==== Testing on site 18 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Accuracy:  0.929
# Precision: 0.375
# Recall:    0.500
# F1 Score:  0.429
# AUC:       0.919
# Negative Predictive Value (NPV): 0.97
# Specificity: 0.953
#
# ==== Testing on site 3 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step
# Accuracy:  0.957
# Precision: 0.200
# Recall:    0.250
# F1 Score:  0.222
# AUC:       0.719
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.975
#
# ==== Testing on site 12 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
# Accuracy:  0.952
# Precision: 0.500
# Recall:    0.125
# F1 Score:  0.200
# AUC:       0.872
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.994
#
# ==== Testing on site 14 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Accuracy:  0.977
# Precision: 0.333
# Recall:    0.200
# F1 Score:  0.250
# AUC:       0.925
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.992
#
# ==== Testing on site 10 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# Accuracy:  0.914
# Precision: 0.600
# Recall:    0.125
# F1 Score:  0.207
# AUC:       0.722
# Negative Predictive Value (NPV): 0.92
# Specificity: 0.992
#
# ==== Testing on site 16 ====
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Accuracy:  0.979
# Precision: 0.600
# Recall:    0.300
# F1 Score:  0.400
# AUC:       0.874
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.995
#
# ==== Testing on site 13 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Accuracy:  0.976
# Precision: 0.500
# Recall:    0.800
# F1 Score:  0.615
# AUC:       0.993
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.980
#
# ==== Testing on site 9 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Accuracy:  0.955
# Precision: 0.500
# Recall:    0.167
# F1 Score:  0.250
# AUC:       0.904
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.992
#
# ==== Testing on site 2 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Accuracy:  0.973
# Precision: 0.250
# Recall:    0.250
# F1 Score:  0.250
# AUC:       0.597
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.986
#
# ==== Testing on site 15 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Accuracy:  0.940
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.844
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.954
#
# ==== Testing on site 19 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy:  0.954
# Precision: 0.375
# Recall:    0.429
# F1 Score:  0.400
# AUC:       0.834
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.973
#
# ==== Testing on site 8 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# Accuracy:  0.957
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.733
# Negative Predictive Value (NPV): 0.97
# Specificity: 0.989
#
# ==== Testing on site 17 ====
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Accuracy:  0.987
# Precision: 0.400
# Recall:    1.000
# F1 Score:  0.571
# AUC:       0.989
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.987
#
# ==== Testing on site 7 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Accuracy:  0.985
# Precision: 0.500
# Recall:    1.000
# F1 Score:  0.667
# AUC:       1.000
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.985
#
# ==== Testing on site 22 ====
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Accuracy:  1.000
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       nan
# Negative Predictive Value (NPV): 1.00
# Specificity: 1.000
# AUC after ablating avgPFCthick_QA: 0.8315
#
# ==== Ablating time-series feature: rsfmri_c_ngd_cgc_ngd_cgc_QA ====
# Baseline features: ['KSADSintern.baseline_year_1_arm_1', 'nihtbx_cryst_agecorrected.baseline_year_1_arm_1', 'ACEs.baseline_year_1_arm_1', 'avgPFCthick_QA.baseline_year_1_arm_1', 'rsfmri_c_ngd_dt_ngd_dt_QA.baseline_year_1_arm_1']
# Follow-up features: ['KSADSintern.2_year_follow_up_y_arm_1', 'nihtbx_cryst_agecorrected.2_year_follow_up_y_arm_1', 'ACEs.2_year_follow_up_y_arm_1', 'avgPFCthick_QA.2_year_follow_up_y_arm_1', 'rsfmri_c_ngd_dt_ngd_dt_QA.2_year_follow_up_y_arm_1']
#
# ==== Testing on site 21 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Accuracy:  0.936
# Precision: 0.500
# Recall:    0.286
# F1 Score:  0.364
# AUC:       0.713
# Negative Predictive Value (NPV): 0.95
# Specificity: 0.980
#
# ==== Testing on site 11 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Accuracy:  0.979
# Precision: 0.500
# Recall:    0.667
# F1 Score:  0.571
# AUC:       0.981
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.985
#
# ==== Testing on site 4 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Accuracy:  0.932
# Precision: 0.273
# Recall:    0.214
# F1 Score:  0.240
# AUC:       0.726
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.970
#
# ==== Testing on site 5 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Accuracy:  0.958
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.803
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 6 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Accuracy:  0.969
# Precision: 0.286
# Recall:    0.400
# F1 Score:  0.333
# AUC:       0.800
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.980
#
# ==== Testing on site 20 ====
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Accuracy:  0.938
# Precision: 0.727
# Recall:    0.308
# F1 Score:  0.432
# AUC:       0.805
# Negative Predictive Value (NPV): 0.94
# Specificity: 0.990
#
# ==== Testing on site 1 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Accuracy:  0.932
# Precision: 0.400
# Recall:    0.333
# F1 Score:  0.364
# AUC:       0.789
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.969
#
# ==== Testing on site 18 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Accuracy:  0.938
# Precision: 0.400
# Recall:    0.333
# F1 Score:  0.364
# AUC:       0.900
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.972
#
# ==== Testing on site 3 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Accuracy:  0.963
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.647
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.988
#
# ==== Testing on site 12 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# Accuracy:  0.958
# Precision: 1.000
# Recall:    0.125
# F1 Score:  0.222
# AUC:       0.779
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 14 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Accuracy:  0.984
# Precision: 0.600
# Recall:    0.600
# F1 Score:  0.600
# AUC:       0.941
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.992
#
# ==== Testing on site 10 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Accuracy:  0.914
# Precision: 0.571
# Recall:    0.167
# F1 Score:  0.258
# AUC:       0.732
# Negative Predictive Value (NPV): 0.92
# Specificity: 0.988
#
# ==== Testing on site 16 ====
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Accuracy:  0.982
# Precision: 0.667
# Recall:    0.400
# F1 Score:  0.500
# AUC:       0.901
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.995
#
# ==== Testing on site 13 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy:  0.986
# Precision: 0.667
# Recall:    0.800
# F1 Score:  0.727
# AUC:       0.982
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.990
#
# ==== Testing on site 9 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy:  0.955
# Precision: 0.500
# Recall:    0.167
# F1 Score:  0.250
# AUC:       0.936
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.992
#
# ==== Testing on site 2 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Accuracy:  0.973
# Precision: 0.250
# Recall:    0.250
# F1 Score:  0.250
# AUC:       0.743
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.986
#
# ==== Testing on site 15 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Accuracy:  0.932
# Precision: 0.111
# Recall:    0.500
# F1 Score:  0.182
# AUC:       0.927
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.939
#
# ==== Testing on site 19 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy:  0.959
# Precision: 0.429
# Recall:    0.429
# F1 Score:  0.429
# AUC:       0.815
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.979
#
# ==== Testing on site 8 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Accuracy:  0.968
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.537
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.989
#
# ==== Testing on site 17 ====
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Accuracy:  0.979
# Precision: 0.286
# Recall:    1.000
# F1 Score:  0.444
# AUC:       0.987
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.978
#
# ==== Testing on site 7 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Accuracy:  0.971
# Precision: 0.333
# Recall:    1.000
# F1 Score:  0.500
# AUC:       1.000
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.970
#
# ==== Testing on site 22 ====
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Accuracy:  1.000
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       nan
# Negative Predictive Value (NPV): 1.00
# Specificity: 1.000
# AUC after ablating rsfmri_c_ngd_cgc_ngd_cgc_QA: 0.8308
#
# ==== Ablating time-series feature: rsfmri_c_ngd_dt_ngd_dt_QA ====
# Baseline features: ['KSADSintern.baseline_year_1_arm_1', 'nihtbx_cryst_agecorrected.baseline_year_1_arm_1', 'ACEs.baseline_year_1_arm_1', 'avgPFCthick_QA.baseline_year_1_arm_1', 'rsfmri_c_ngd_cgc_ngd_cgc_QA.baseline_year_1_arm_1']
# Follow-up features: ['KSADSintern.2_year_follow_up_y_arm_1', 'nihtbx_cryst_agecorrected.2_year_follow_up_y_arm_1', 'ACEs.2_year_follow_up_y_arm_1', 'avgPFCthick_QA.2_year_follow_up_y_arm_1', 'rsfmri_c_ngd_cgc_ngd_cgc_QA.2_year_follow_up_y_arm_1']
#
# ==== Testing on site 21 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Accuracy:  0.940
# Precision: 0.571
# Recall:    0.286
# F1 Score:  0.381
# AUC:       0.719
# Negative Predictive Value (NPV): 0.95
# Specificity: 0.985
#
# ==== Testing on site 11 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Accuracy:  0.979
# Precision: 0.500
# Recall:    0.667
# F1 Score:  0.571
# AUC:       0.995
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.985
#
# ==== Testing on site 4 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Accuracy:  0.936
# Precision: 0.250
# Recall:    0.143
# F1 Score:  0.182
# AUC:       0.697
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.978
#
# ==== Testing on site 5 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Accuracy:  0.933
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.718
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.974
#
# ==== Testing on site 6 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Accuracy:  0.969
# Precision: 0.286
# Recall:    0.400
# F1 Score:  0.333
# AUC:       0.900
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.980
#
# ==== Testing on site 20 ====
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# Accuracy:  0.926
# Precision: 0.556
# Recall:    0.192
# F1 Score:  0.286
# AUC:       0.792
# Negative Predictive Value (NPV): 0.94
# Specificity: 0.987
#
# ==== Testing on site 1 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Accuracy:  0.942
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.782
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.979
#
# ==== Testing on site 18 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Accuracy:  0.947
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.891
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.981
#
# ==== Testing on site 3 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Accuracy:  0.970
# Precision: 0.333
# Recall:    0.250
# F1 Score:  0.286
# AUC:       0.759
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.988
#
# ==== Testing on site 12 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Accuracy:  0.952
# Precision: 0.500
# Recall:    0.125
# F1 Score:  0.200
# AUC:       0.872
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.994
#
# ==== Testing on site 14 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Accuracy:  0.988
# Precision: 1.000
# Recall:    0.400
# F1 Score:  0.571
# AUC:       0.932
# Negative Predictive Value (NPV): 0.99
# Specificity: 1.000
#
# ==== Testing on site 10 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Accuracy:  0.917
# Precision: 0.750
# Recall:    0.125
# F1 Score:  0.214
# AUC:       0.720
# Negative Predictive Value (NPV): 0.92
# Specificity: 0.996
#
# ==== Testing on site 16 ====
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Accuracy:  0.979
# Precision: 0.600
# Recall:    0.300
# F1 Score:  0.400
# AUC:       0.897
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.995
#
# ==== Testing on site 13 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Accuracy:  0.981
# Precision: 0.600
# Recall:    0.600
# F1 Score:  0.600
# AUC:       0.979
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.990
#
# ==== Testing on site 9 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Accuracy:  0.963
# Precision: 1.000
# Recall:    0.167
# F1 Score:  0.286
# AUC:       0.883
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 2 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Accuracy:  0.977
# Precision: 0.333
# Recall:    0.250
# F1 Score:  0.286
# AUC:       0.650
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.991
#
# ==== Testing on site 15 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Accuracy:  0.940
# Precision: 0.125
# Recall:    0.500
# F1 Score:  0.200
# AUC:       0.927
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.947
#
# ==== Testing on site 19 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy:  0.959
# Precision: 0.429
# Recall:    0.429
# F1 Score:  0.429
# AUC:       0.876
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.979
#
# ==== Testing on site 8 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Accuracy:  0.968
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.763
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.989
#
# ==== Testing on site 17 ====
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Accuracy:  0.987
# Precision: 0.400
# Recall:    1.000
# F1 Score:  0.571
# AUC:       0.991
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.987
#
# ==== Testing on site 7 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Accuracy:  0.971
# Precision: 0.333
# Recall:    1.000
# F1 Score:  0.500
# AUC:       1.000
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.970
#
# ==== Testing on site 22 ====
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Accuracy:  1.000
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       nan
# Negative Predictive Value (NPV): 1.00
# Specificity: 1.000
# AUC after ablating rsfmri_c_ngd_dt_ngd_dt_QA: 0.8450

# %%
print("\nAblating cross-sectional features...\n")

# Load existing ablations from CSV
existing_ablated = get_existing_ablated_features(csv_file)

for cross_feat in cross_sectional_features:
    if cross_feat in existing_ablated:
        print(f"Skipping {cross_feat} — already in results.")
        continue

    print(f"\n==== Ablating cross-sectional feature: {cross_feat} ====")

    cross_sectional_ablate = [f for f in cross_sectional_features if f != cross_feat]

    metrics = run_losocv_lstm(
        df,
        features_baseline=features_baseline,
        features_followup=features_followup,
        cross_sectional_features=cross_sectional_ablate,
        verbose=0
    )

    mean_metrics = {
        'ablated_feature': cross_feat,
        'feature_type': 'cross_feat',
        'Accuracy': np.nanmean([m[1] for m in metrics]),
        'Precision': np.nanmean([m[2] for m in metrics]),
        'Recall': np.nanmean([m[3] for m in metrics]),
        'NPV': np.nanmean([m[4] for m in metrics]),
        'AUC': np.nanmean([m[5] for m in metrics]),
        'Specificity': np.nanmean([m[6] for m in metrics]),
        'F1 Score': np.nanmean([m[7] for m in metrics])
    }

    results.append(mean_metrics)
    write_result_to_csv(mean_metrics)
    print(f"AUC after ablating {cross_feat}: {mean_metrics['AUC']:.4f}")
# Out:
# Ablating cross-sectional features...
#
#
# ==== Ablating cross-sectional feature: rel_family_id ====
#
# ==== Testing on site 21 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Accuracy:  0.936
# Precision: 0.500
# Recall:    0.286
# F1 Score:  0.364
# AUC:       0.701
# Negative Predictive Value (NPV): 0.95
# Specificity: 0.980
#
# ==== Testing on site 11 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Accuracy:  0.979
# Precision: 0.500
# Recall:    0.667
# F1 Score:  0.571
# AUC:       0.993
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.985
#
# ==== Testing on site 4 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# Accuracy:  0.940
# Precision: 0.333
# Recall:    0.214
# F1 Score:  0.261
# AUC:       0.673
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.978
#
# ==== Testing on site 5 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Accuracy:  0.942
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.748
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.983
#
# ==== Testing on site 6 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Accuracy:  0.977
# Precision: 0.400
# Recall:    0.400
# F1 Score:  0.400
# AUC:       0.818
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.988
#
# ==== Testing on site 20 ====
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Accuracy:  0.932
# Precision: 0.714
# Recall:    0.192
# F1 Score:  0.303
# AUC:       0.798
# Negative Predictive Value (NPV): 0.94
# Specificity: 0.994
#
# ==== Testing on site 1 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Accuracy:  0.951
# Precision: 0.667
# Recall:    0.333
# F1 Score:  0.444
# AUC:       0.818
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.990
#
# ==== Testing on site 18 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Accuracy:  0.929
# Precision: 0.333
# Recall:    0.333
# F1 Score:  0.333
# AUC:       0.886
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.963
#
# ==== Testing on site 3 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Accuracy:  0.970
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.708
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.994
#
# ==== Testing on site 12 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Accuracy:  0.952
# Precision: 0.500
# Recall:    0.250
# F1 Score:  0.333
# AUC:       0.818
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.987
#
# ==== Testing on site 14 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Accuracy:  0.992
# Precision: 0.800
# Recall:    0.800
# F1 Score:  0.800
# AUC:       0.906
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.996
#
# ==== Testing on site 10 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy:  0.914
# Precision: 0.571
# Recall:    0.167
# F1 Score:  0.258
# AUC:       0.776
# Negative Predictive Value (NPV): 0.92
# Specificity: 0.988
#
# ==== Testing on site 16 ====
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Accuracy:  0.982
# Precision: 0.667
# Recall:    0.400
# F1 Score:  0.500
# AUC:       0.873
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.995
#
# ==== Testing on site 13 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step
# Accuracy:  0.986
# Precision: 1.000
# Recall:    0.400
# F1 Score:  0.571
# AUC:       0.921
# Negative Predictive Value (NPV): 0.99
# Specificity: 1.000
#
# ==== Testing on site 9 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy:  0.963
# Precision: 1.000
# Recall:    0.167
# F1 Score:  0.286
# AUC:       0.911
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 2 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Accuracy:  0.973
# Precision: 0.250
# Recall:    0.250
# F1 Score:  0.250
# AUC:       0.658
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.986
#
# ==== Testing on site 15 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Accuracy:  0.947
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.924
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.962
#
# ==== Testing on site 19 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Accuracy:  0.954
# Precision: 0.375
# Recall:    0.429
# F1 Score:  0.400
# AUC:       0.864
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.973
#
# ==== Testing on site 8 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Accuracy:  0.957
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.715
# Negative Predictive Value (NPV): 0.97
# Specificity: 0.989
#
# ==== Testing on site 17 ====
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Accuracy:  0.987
# Precision: 0.400
# Recall:    1.000
# F1 Score:  0.571
# AUC:       0.987
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.987
#
# ==== Testing on site 7 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Accuracy:  0.971
# Precision: 0.333
# Recall:    1.000
# F1 Score:  0.500
# AUC:       1.000
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.970
#
# ==== Testing on site 22 ====
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Accuracy:  1.000
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       nan
# Negative Predictive Value (NPV): 1.00
# Specificity: 1.000
# AUC after ablating rel_family_id: 0.8331
#
# ==== Ablating cross-sectional feature: acs_raked_propensity_score ====
#
# ==== Testing on site 21 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Accuracy:  0.940
# Precision: 0.571
# Recall:    0.286
# F1 Score:  0.381
# AUC:       0.698
# Negative Predictive Value (NPV): 0.95
# Specificity: 0.985
#
# ==== Testing on site 11 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Accuracy:  0.971
# Precision: 0.400
# Recall:    0.667
# F1 Score:  0.500
# AUC:       0.961
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.978
#
# ==== Testing on site 4 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Accuracy:  0.940
# Precision: 0.333
# Recall:    0.214
# F1 Score:  0.261
# AUC:       0.736
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.978
#
# ==== Testing on site 5 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Accuracy:  0.950
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.682
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.991
#
# ==== Testing on site 6 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Accuracy:  0.973
# Precision: 0.333
# Recall:    0.400
# F1 Score:  0.364
# AUC:       0.780
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.984
#
# ==== Testing on site 20 ====
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Accuracy:  0.935
# Precision: 0.750
# Recall:    0.231
# F1 Score:  0.353
# AUC:       0.838
# Negative Predictive Value (NPV): 0.94
# Specificity: 0.994
#
# ==== Testing on site 1 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Accuracy:  0.942
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.806
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.979
#
# ==== Testing on site 18 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step
# Accuracy:  0.920
# Precision: 0.286
# Recall:    0.333
# F1 Score:  0.308
# AUC:       0.894
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.953
#
# ==== Testing on site 3 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Accuracy:  0.963
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.627
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.988
#
# ==== Testing on site 12 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Accuracy:  0.958
# Precision: 1.000
# Recall:    0.125
# F1 Score:  0.222
# AUC:       0.791
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 14 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy:  0.984
# Precision: 0.667
# Recall:    0.400
# F1 Score:  0.500
# AUC:       0.934
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.996
#
# ==== Testing on site 10 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Accuracy:  0.917
# Precision: 0.625
# Recall:    0.208
# F1 Score:  0.312
# AUC:       0.756
# Negative Predictive Value (NPV): 0.93
# Specificity: 0.988
#
# ==== Testing on site 16 ====
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Accuracy:  0.984
# Precision: 0.800
# Recall:    0.400
# F1 Score:  0.533
# AUC:       0.881
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.998
#
# ==== Testing on site 13 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Accuracy:  0.976
# Precision: 0.500
# Recall:    0.800
# F1 Score:  0.615
# AUC:       0.986
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.980
#
# ==== Testing on site 9 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Accuracy:  0.963
# Precision: 1.000
# Recall:    0.167
# F1 Score:  0.286
# AUC:       0.910
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 2 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
# Accuracy:  0.973
# Precision: 0.250
# Recall:    0.250
# F1 Score:  0.250
# AUC:       0.626
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.986
#
# ==== Testing on site 15 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Accuracy:  0.955
# Precision: 0.167
# Recall:    0.500
# F1 Score:  0.250
# AUC:       0.905
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.962
#
# ==== Testing on site 19 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Accuracy:  0.959
# Precision: 0.429
# Recall:    0.429
# F1 Score:  0.429
# AUC:       0.855
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.979
#
# ==== Testing on site 8 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Accuracy:  0.957
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.726
# Negative Predictive Value (NPV): 0.97
# Specificity: 0.989
#
# ==== Testing on site 17 ====
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Accuracy:  0.983
# Precision: 0.250
# Recall:    0.500
# F1 Score:  0.333
# AUC:       0.985
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.987
#
# ==== Testing on site 7 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Accuracy:  0.971
# Precision: 0.333
# Recall:    1.000
# F1 Score:  0.500
# AUC:       1.000
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.970
#
# ==== Testing on site 22 ====
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# Accuracy:  0.875
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       nan
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.875
# AUC after ablating acs_raked_propensity_score: 0.8274
#
# ==== Ablating cross-sectional feature: speechdelays ====
#
# ==== Testing on site 21 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# Accuracy:  0.945
# Precision: 0.667
# Recall:    0.286
# F1 Score:  0.400
# AUC:       0.739
# Negative Predictive Value (NPV): 0.95
# Specificity: 0.990
#
# ==== Testing on site 11 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Accuracy:  0.979
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.995
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.993
#
# ==== Testing on site 4 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# Accuracy:  0.936
# Precision: 0.300
# Recall:    0.214
# F1 Score:  0.250
# AUC:       0.673
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.974
#
# ==== Testing on site 5 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Accuracy:  0.950
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.784
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.991
#
# ==== Testing on site 6 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Accuracy:  0.969
# Precision: 0.286
# Recall:    0.400
# F1 Score:  0.333
# AUC:       0.794
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.980
#
# ==== Testing on site 20 ====
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Accuracy:  0.929
# Precision: 0.625
# Recall:    0.192
# F1 Score:  0.294
# AUC:       0.819
# Negative Predictive Value (NPV): 0.94
# Specificity: 0.990
#
# ==== Testing on site 1 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy:  0.942
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.811
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.979
#
# ==== Testing on site 18 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Accuracy:  0.938
# Precision: 0.429
# Recall:    0.500
# F1 Score:  0.462
# AUC:       0.924
# Negative Predictive Value (NPV): 0.97
# Specificity: 0.963
#
# ==== Testing on site 3 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Accuracy:  0.963
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.702
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.988
#
# ==== Testing on site 12 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step
# Accuracy:  0.952
# Precision: 0.500
# Recall:    0.250
# F1 Score:  0.333
# AUC:       0.836
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.987
#
# ==== Testing on site 14 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# Accuracy:  0.984
# Precision: 0.571
# Recall:    0.800
# F1 Score:  0.667
# AUC:       0.902
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.988
#
# ==== Testing on site 10 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Accuracy:  0.917
# Precision: 0.625
# Recall:    0.208
# F1 Score:  0.312
# AUC:       0.764
# Negative Predictive Value (NPV): 0.93
# Specificity: 0.988
#
# ==== Testing on site 16 ====
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Accuracy:  0.982
# Precision: 0.667
# Recall:    0.400
# F1 Score:  0.500
# AUC:       0.886
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.995
#
# ==== Testing on site 13 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step
# Accuracy:  0.990
# Precision: 0.800
# Recall:    0.800
# F1 Score:  0.800
# AUC:       0.980
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.995
#
# ==== Testing on site 9 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Accuracy:  0.963
# Precision: 1.000
# Recall:    0.167
# F1 Score:  0.286
# AUC:       0.928
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 2 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Accuracy:  0.968
# Precision: 0.200
# Recall:    0.250
# F1 Score:  0.222
# AUC:       0.650
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.981
#
# ==== Testing on site 15 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Accuracy:  0.940
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.855
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.954
#
# ==== Testing on site 19 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Accuracy:  0.964
# Precision: 0.500
# Recall:    0.429
# F1 Score:  0.462
# AUC:       0.851
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.984
#
# ==== Testing on site 8 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# Accuracy:  0.968
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.748
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.989
#
# ==== Testing on site 17 ====
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Accuracy:  0.987
# Precision: 0.400
# Recall:    1.000
# F1 Score:  0.571
# AUC:       0.989
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.987
#
# ==== Testing on site 7 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Accuracy:  0.971
# Precision: 0.333
# Recall:    1.000
# F1 Score:  0.500
# AUC:       1.000
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.970
#
# ==== Testing on site 22 ====
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Accuracy:  1.000
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       nan
# Negative Predictive Value (NPV): 1.00
# Specificity: 1.000
# AUC after ablating speechdelays: 0.8396
#
# ==== Ablating cross-sectional feature: motordelays ====
#
# ==== Testing on site 21 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Accuracy:  0.940
# Precision: 0.571
# Recall:    0.286
# F1 Score:  0.381
# AUC:       0.726
# Negative Predictive Value (NPV): 0.95
# Specificity: 0.985
#
# ==== Testing on site 11 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Accuracy:  0.979
# Precision: 0.500
# Recall:    0.667
# F1 Score:  0.571
# AUC:       0.966
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.985
#
# ==== Testing on site 4 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Accuracy:  0.932
# Precision: 0.222
# Recall:    0.143
# F1 Score:  0.174
# AUC:       0.666
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.974
#
# ==== Testing on site 5 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Accuracy:  0.950
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.727
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.991
#
# ==== Testing on site 6 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy:  0.973
# Precision: 0.333
# Recall:    0.400
# F1 Score:  0.364
# AUC:       0.886
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.984
#
# ==== Testing on site 20 ====
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Accuracy:  0.941
# Precision: 0.750
# Recall:    0.346
# F1 Score:  0.474
# AUC:       0.807
# Negative Predictive Value (NPV): 0.95
# Specificity: 0.990
#
# ==== Testing on site 1 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Accuracy:  0.942
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.842
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.979
#
# ==== Testing on site 18 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Accuracy:  0.938
# Precision: 0.400
# Recall:    0.333
# F1 Score:  0.364
# AUC:       0.889
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.972
#
# ==== Testing on site 3 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Accuracy:  0.963
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.795
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.988
#
# ==== Testing on site 12 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Accuracy:  0.945
# Precision: 0.333
# Recall:    0.125
# F1 Score:  0.182
# AUC:       0.877
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.987
#
# ==== Testing on site 14 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Accuracy:  0.981
# Precision: 0.500
# Recall:    0.400
# F1 Score:  0.444
# AUC:       0.935
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.992
#
# ==== Testing on site 10 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Accuracy:  0.917
# Precision: 0.667
# Recall:    0.167
# F1 Score:  0.267
# AUC:       0.738
# Negative Predictive Value (NPV): 0.92
# Specificity: 0.992
#
# ==== Testing on site 16 ====
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Accuracy:  0.984
# Precision: 0.800
# Recall:    0.400
# F1 Score:  0.533
# AUC:       0.885
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.998
#
# ==== Testing on site 13 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Accuracy:  0.976
# Precision: 0.500
# Recall:    0.800
# F1 Score:  0.615
# AUC:       0.974
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.980
#
# ==== Testing on site 9 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step
# Accuracy:  0.963
# Precision: 1.000
# Recall:    0.167
# F1 Score:  0.286
# AUC:       0.913
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 2 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Accuracy:  0.982
# Precision: 0.500
# Recall:    0.250
# F1 Score:  0.333
# AUC:       0.740
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.995
#
# ==== Testing on site 15 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# Accuracy:  0.932
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.885
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.947
#
# ==== Testing on site 19 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Accuracy:  0.964
# Precision: 0.500
# Recall:    0.429
# F1 Score:  0.462
# AUC:       0.812
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.984
#
# ==== Testing on site 8 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Accuracy:  0.968
# Precision: 0.500
# Recall:    0.333
# F1 Score:  0.400
# AUC:       0.748
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.989
#
# ==== Testing on site 17 ====
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step
# Accuracy:  0.979
# Precision: 0.286
# Recall:    1.000
# F1 Score:  0.444
# AUC:       0.987
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.978
#
# ==== Testing on site 7 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step
# Accuracy:  0.971
# Precision: 0.333
# Recall:    1.000
# F1 Score:  0.500
# AUC:       1.000
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.970
#
# ==== Testing on site 22 ====
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Accuracy:  0.875
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       nan
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.875
# AUC after ablating motordelays: 0.8476
#
# ==== Ablating cross-sectional feature: fam_history_8_yes_no ====
#
# ==== Testing on site 21 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# Accuracy:  0.927
# Precision: 0.400
# Recall:    0.286
# F1 Score:  0.333
# AUC:       0.728
# Negative Predictive Value (NPV): 0.95
# Specificity: 0.971
#
# ==== Testing on site 11 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Accuracy:  0.979
# Precision: 0.500
# Recall:    0.667
# F1 Score:  0.571
# AUC:       0.990
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.985
#
# ==== Testing on site 4 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Accuracy:  0.936
# Precision: 0.300
# Recall:    0.214
# F1 Score:  0.250
# AUC:       0.688
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.974
#
# ==== Testing on site 5 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Accuracy:  0.950
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.718
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.991
#
# ==== Testing on site 6 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Accuracy:  0.965
# Precision: 0.300
# Recall:    0.600
# F1 Score:  0.400
# AUC:       0.839
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.972
#
# ==== Testing on site 20 ====
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Accuracy:  0.935
# Precision: 0.750
# Recall:    0.231
# F1 Score:  0.353
# AUC:       0.837
# Negative Predictive Value (NPV): 0.94
# Specificity: 0.994
#
# ==== Testing on site 1 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Accuracy:  0.951
# Precision: 0.667
# Recall:    0.333
# F1 Score:  0.444
# AUC:       0.840
# Negative Predictive Value (NPV): 0.96
# Specificity: 0.990
#
# ==== Testing on site 18 ====
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Accuracy:  0.938
# Precision: 0.429
# Recall:    0.500
# F1 Score:  0.462
# AUC:       0.939
# Negative Predictive Value (NPV): 0.97
# Specificity: 0.963
#
# ==== Testing on site 3 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Accuracy:  0.963
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.655
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.988
#
# ==== Testing on site 12 ====
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Accuracy:  0.958
# Precision: 1.000
# Recall:    0.125
# F1 Score:  0.222
# AUC:       0.844
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 14 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Accuracy:  0.984
# Precision: 0.667
# Recall:    0.400
# F1 Score:  0.500
# AUC:       0.934
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.996
#
# ==== Testing on site 10 ====
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Accuracy:  0.917
# Precision: 0.667
# Recall:    0.167
# F1 Score:  0.267
# AUC:       0.750
# Negative Predictive Value (NPV): 0.92
# Specificity: 0.992
#
# ==== Testing on site 16 ====
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Accuracy:  0.982
# Precision: 0.750
# Recall:    0.300
# F1 Score:  0.429
# AUC:       0.881
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.998
#
# ==== Testing on site 13 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy:  0.976
# Precision: 0.500
# Recall:    0.600
# F1 Score:  0.545
# AUC:       0.975
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.985
#
# ==== Testing on site 9 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Accuracy:  0.963
# Precision: 1.000
# Recall:    0.167
# F1 Score:  0.286
# AUC:       0.909
# Negative Predictive Value (NPV): 0.96
# Specificity: 1.000
#
# ==== Testing on site 2 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Accuracy:  0.977
# Precision: 0.333
# Recall:    0.250
# F1 Score:  0.286
# AUC:       0.715
# Negative Predictive Value (NPV): 0.99
# Specificity: 0.991
#
# ==== Testing on site 15 ====
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Accuracy:  0.955
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.832
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.969
#
# ==== Testing on site 19 ====
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Accuracy:  0.969
# Precision: 0.600
# Recall:    0.429
# F1 Score:  0.500
# AUC:       0.840
# Negative Predictive Value (NPV): 0.98
# Specificity: 0.989
#
# ==== Testing on site 8 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Accuracy:  0.957
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       0.711
# Negative Predictive Value (NPV): 0.97
# Specificity: 0.989
#
# ==== Testing on site 17 ====
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Accuracy:  0.987
# Precision: 0.400
# Recall:    1.000
# F1 Score:  0.571
# AUC:       0.987
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.987
#
# ==== Testing on site 7 ====
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Accuracy:  0.971
# Precision: 0.333
# Recall:    1.000
# F1 Score:  0.500
# AUC:       1.000
# Negative Predictive Value (NPV): 1.00
# Specificity: 0.970
#
# ==== Testing on site 22 ====
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# Accuracy:  1.000
# Precision: 0.000
# Recall:    0.000
# F1 Score:  0.000
# AUC:       nan
# Negative Predictive Value (NPV): 1.00
# Specificity: 1.000
# AUC after ablating fam_history_8_yes_no: 0.8387

# %%
df_results = pd.DataFrame(results)
df_results_sorted = df_results.sort_values(by='AUC', ascending=True)
print(df_results_sorted)
# Out:
#                 ablated_feature feature_type  Accuracy  Precision    Recall  \
# 0                   KSADSintern  time_series  0.963207   0.060606  0.020455
# 7    acs_raked_propensity_score   cross_feat  0.954017   0.417911  0.329212
# 4   rsfmri_c_ngd_cgc_ngd_cgc_QA  time_series  0.959282   0.409055  0.377785
# 3                avgPFCthick_QA  time_series  0.957616   0.358658  0.330728
# 6                 rel_family_id   cross_feat  0.960457   0.424729  0.331252
# 2                          ACEs  time_series  0.955818   0.405195  0.359282
# 10         fam_history_8_yes_no   cross_feat  0.960892   0.436147  0.330349
# 8                  speechdelays   cross_feat  0.960726   0.427381  0.358904
# 1     nihtbx_cryst_agecorrected  time_series  0.961975   0.484524  0.366188
# 5     rsfmri_c_ngd_dt_ngd_dt_QA  time_series  0.960125   0.457558  0.356036
# 9                   motordelays   cross_feat  0.954282   0.418001  0.344468
#
#          NPV       AUC  Specificity  F1 Score
# 0   0.964710  0.671916     0.998409  0.029545
# 7   0.973753  0.827408     0.979067  0.308961
# 4   0.974686  0.830755     0.983339  0.337750
# 3   0.973608  0.831476     0.982669  0.305193
# 6   0.973490  0.833111     0.985785  0.324851
# 2   0.974449  0.834125     0.980216  0.343037
# 10  0.973731  0.838726     0.986047  0.314521
# 8   0.974651  0.839611     0.984870  0.345109
# 1   0.974753  0.840297     0.986132  0.367870
# 5   0.973785  0.845032     0.985216  0.340732
# 9   0.974159  0.847555     0.978940  0.326997
